# %% [markdown]
# ## Translation

# %%
from datasets import load_dataset
raw_datasets = load_dataset("kde4", lang1="en", lang2="fr")
# Out:
# README.md: 0.00B [00:00, ?B/s]
# kde4.py: 0.00B [00:00, ?B/s]
# Downloading data:   0%|          | 0.00/7.05M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/210173 [00:00<?, ? examples/s]

# %%
raw_datasets
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['id', 'translation'],
#         num_rows: 210173
#     })
# })

# %%
raw_datasets["train"][:3]
# Out:
# {'id': ['0', '1', '2'],
#  'translation': [{'en': 'Lauri Watts', 'fr': 'Lauri Watts'},
#   {'en': '& Lauri. Watts. mail;', 'fr': '& Lauri. Watts. mail;'},
#   {'en': 'ROLES_OF_TRANSLATORS', 'fr': '& traducteurJeromeBlanc;'}]}

# %%
# Split into train and test
split_datasets = raw_datasets["train"].train_test_split(test_size=0.1, seed=42)
split_datasets
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['id', 'translation'],
#         num_rows: 189155
#     })
#     test: Dataset({
#         features: ['id', 'translation'],
#         num_rows: 21018
#     })
# })

# %%
split_datasets["validation"] = split_datasets["test"]

# %%
split_datasets
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['id', 'translation'],
#         num_rows: 189155
#     })
#     test: Dataset({
#         features: ['id', 'translation'],
#         num_rows: 21018
#     })
#     validation: Dataset({
#         features: ['id', 'translation'],
#         num_rows: 21018
#     })
# })

# %%
# Load the pretrained model
from transformers import pipeline
model_checkpoint = "Helsinki-NLP/opus-mt-en-fr"
translator = pipeline("translation", model=model_checkpoint)
translator("Default to expanded threads")
# Out:
# config.json: 0.00B [00:00, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/301M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/293 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/301M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/42.0 [00:00<?, ?B/s]
# source.spm:   0%|          | 0.00/778k [00:00<?, ?B/s]
# target.spm:   0%|          | 0.00/802k [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# /root/workspace/projects/hf_llm/.venv/lib/python3.12/site-packages/transformers/models/marian/tokenization_marian.py:175: UserWarning: Recommended: pip install sacremoses.
#   warnings.warn("Recommended: pip install sacremoses.")
# Device set to use cuda:0
# [{'translation_text': 'Par défaut pour les threads élargis'}]
