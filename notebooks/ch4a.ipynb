# %%
import pprint
from transformers.pipelines import PIPELINE_REGISTRY
pprint.pprint(list(PIPELINE_REGISTRY.supported_tasks.keys()))
# Out:
# ['audio-classification',
#  'automatic-speech-recognition',
#  'text-to-audio',
#  'feature-extraction',
#  'text-classification',
#  'token-classification',
#  'question-answering',
#  'table-question-answering',
#  'visual-question-answering',
#  'document-question-answering',
#  'fill-mask',
#  'summarization',
#  'translation',
#  'text2text-generation',
#  'text-generation',
#  'zero-shot-classification',
#  'zero-shot-image-classification',
#  'zero-shot-audio-classification',
#  'image-classification',
#  'image-feature-extraction',
#  'image-segmentation',
#  'image-to-text',
#  'image-text-to-text',
#  'object-detection',
#  'zero-shot-object-detection',
#  'depth-estimation',
#  'video-classification',
#  'mask-generation',
#  'image-to-image',
#  'keypoint-matching']

# %%
from huggingface_hub import list_models

models = list_models(
    filter="text-classification",
    sort="downloads",
    direction=-1,  # Descending
    limit=10,
)

for m in models:
    print(f"{m.downloads:>10,}  {m.id}")
# Out:
#  6,997,036  cross-encoder/ms-marco-MiniLM-L6-v2
#  4,744,800  distilbert/distilbert-base-uncased-finetuned-sst-2-english
#  4,050,751  facebook/bart-large-mnli
#  3,727,710  cardiffnlp/twitter-roberta-base-sentiment-latest
#  2,889,205  microsoft/deberta-xlarge-mnli
#  2,828,747  BAAI/bge-reranker-v2-m3
#  2,776,862  ProsusAI/finbert
#  2,717,752  yiyanghkust/finbert-tone
#  1,609,772  kmack/malicious-url-detection
#  1,424,151  cross-encoder/ms-marco-MiniLM-L4-v2

# %%
# Clone my hf repo to a local directory
from huggingface_hub import Repository
repo = Repository(
    local_dir="../data/test_hf_repo_cloned", 
    clone_from="tensor-polinomics/mrpc-bert-test")
# Out:
# /workspace/hf_llm/.venv/lib/python3.12/site-packages/huggingface_hub/utils/_deprecation.py:131: FutureWarning: 'Repository' (from 'huggingface_hub.repository') is deprecated and will be removed from version '1.0'. Please prefer the http-based alternatives instead. Given its large adoption in legacy code, the complete removal is only planned on next major release.
# For more details, please read https://huggingface.co/docs/huggingface_hub/concepts/git_vs_http.
#   warnings.warn(warning_message, FutureWarning)
# Cloning https://huggingface.co/tensor-polinomics/mrpc-bert-test into local empty directory.
# Download file runs/Dec07_19-07-12_4aa9e204d04d/events.out.tfevents.1765134445.4aa9e204d04d.4695.0: 100%|######…
# Download file training_args.bin: 100%|##########| 5.77k/5.77k [00:00<?, ?B/s]
# Download file runs/Dec07_18-28-36_4aa9e204d04d/events.out.tfevents.1765132118.4aa9e204d04d.2898.0: 100%|######…
# Download file runs/Dec07_19-03-36_4aa9e204d04d/events.out.tfevents.1765134217.4aa9e204d04d.3919.0:  28%|##8   …
# Download file runs/Dec07_18-38-44_4aa9e204d04d/events.out.tfevents.1765132726.4aa9e204d04d.3577.0: 100%|######…
# Download file model.safetensors:   0%|          | 8.00k/418M [00:00<?, ?B/s]
# Clean file runs/Dec07_19-07-12_4aa9e204d04d/events.out.tfevents.1765134445.4aa9e204d04d.4695.0:  20%|##       …
# Clean file training_args.bin:  17%|#7        | 1.00k/5.77k [00:00<?, ?B/s]
# Clean file runs/Dec07_18-28-36_4aa9e204d04d/events.out.tfevents.1765132118.4aa9e204d04d.2898.0:  20%|##       …
# Clean file runs/Dec07_19-03-36_4aa9e204d04d/events.out.tfevents.1765134217.4aa9e204d04d.3919.0:  20%|##       …
# Clean file runs/Dec07_18-38-44_4aa9e204d04d/events.out.tfevents.1765132726.4aa9e204d04d.3577.0:  20%|##       …
# Clean file model.safetensors:   0%|          | 1.00k/418M [00:00<?, ?B/s]
